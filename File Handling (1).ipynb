# %%
f = open("kalyan.txt", "r")
print(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 f = open("kalyan.txt", "r")
#       2 print(f)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kalyan.txt'

# %%
file = open('filename.txt', 'mode')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 file = open('filename.txt', 'mode')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# ValueError: invalid mode: 'mode'

# %%
with open("C:\DKB\Darla\DA & DS\geek.txt", "w") as file:
    file.write("Hello, Python!\n")
    file.write("File handling is easy with Python.")

print("File written successfully")
# Out:
# File written successfully

# %%
#file handling

f = open("kalyan.txt","w")
f.write("welcome")
f.close()
print("file written successfully")
# Out:
# file written successfully

# %%
#file handling

with open("kalyan.txt","r") as f:
    # f.write("welcome")
    # f.close()
    content = f.read()
print(content)
print("file written successfully")
# Out:
# welcome
# file written successfully

# %%
f = open("kalyan.txt","a")
f.write("\nwelcome to india")
f.close()
with open("kalyan.txt","r") as f:
    content = f.read()
print(content)
print("file written successfully")
# Out:
# welcomewelcome to indiawelcome to india
# welcome to india
# welcome to india
# welcome to india
#  welcome to india
# welcome to india
# welcome to india
# welcome to india
# file written successfully

# %%
import os
os.remove("kalyan.txt")
with open("kalyan.txt","r") as f:
    content = f.read()
print(content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 3
#       1 import os
#       2 os.remove("kalyan.txt")
# ----> 3 with open("kalyan.txt","r") as f:
#       4     content = f.read()
#       5 print(content)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kalyan.txt'
